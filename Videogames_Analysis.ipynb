# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamizhPrashanth/pandas-data-analysis-insights/blob/main/Videogames_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Video_Games_df = pd.read_csv("/content/Video_Games.csv")

# %%
Video_Games_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
Video_Games_df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
Video_Games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
Video_Games_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
Video_Games_df['Name'][0:10]
# Out:
# 0                   Wii Sports
# 1            Super Mario Bros.
# 2               Mario Kart Wii
# 3            Wii Sports Resort
# 4     Pokemon Red/Pokemon Blue
# 5                       Tetris
# 6        New Super Mario Bros.
# 7                     Wii Play
# 8    New Super Mario Bros. Wii
# 9                    Duck Hunt
# Name: Name, dtype: object

# %%
Video_Games_df.iloc[1:4]
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 2     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
# 3  Wii Sports Resort      Wii           2009.0    Sports  Nintendo     15.61
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 2     12.76      3.79         3.29         35.52          82.0          73.0
# 3     10.93      3.28         2.95         32.77          80.0          73.0
#
#   User_Score  User_Count Developer Rating
# 1        NaN         NaN       NaN    NaN
# 2        8.3       709.0  Nintendo      E
# 3          8       192.0  Nintendo      E

# %%
Video_Games_df.iloc[7,5]
# Out:
# 13.96

# %%
Video_Games_df.sort_values(['Name', 'Global_Sales'], ascending=[0,1])
# Out:
#                                Name Platform  Year_of_Release         Genre  \
# 9135   ¡Shin Chan Flipa en colores!       DS           2007.0      Platform
# 475      wwe Smackdown vs. Raw 2006      PS2              NaN      Fighting
# 15614  uDraw Studio: Instant Artist     X360           2011.0          Misc
# 8281   uDraw Studio: Instant Artist      Wii           2011.0          Misc
# 645                    uDraw Studio      Wii           2010.0          Misc
# ...                             ...      ...              ...           ...
# 3358           Frozen: Olaf's Quest      3DS           2013.0      Platform
# 1079              Fire Emblem Fates      3DS           2015.0  Role-Playing
# 14985                Beyblade Burst      3DS           2016.0  Role-Playing
# 14246                           NaN      GEN           1993.0           NaN
# 659                             NaN      GEN           1993.0           NaN
#
# ...

# %%
Video_Games_df.loc[Video_Games_df['Global_Sales'] > 30 ]
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
# 5                    Tetris       GB           1989.0        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# ...

# %%
Filtered_GlobalSales_Data =Video_Games_df.loc[Video_Games_df['Global_Sales'] > 30 ]

# %%
Filtered_GlobalSales_Data.to_csv("Filtered_GlobalSales_Data.csv")

# %%
Sales_Data_Df = pd.read_csv("/content/Filtered_GlobalSales_Data.csv")

# %%
Sales_Data_Df
# Out:
#    Unnamed: 0                      Name Platform  Year_of_Release  \
# 0           0                Wii Sports      Wii           2006.0
# 1           1         Super Mario Bros.      NES           1985.0
# 2           2            Mario Kart Wii      Wii           2008.0
# 3           3         Wii Sports Resort      Wii           2009.0
# 4           4  Pokemon Red/Pokemon Blue       GB           1996.0
# 5           5                    Tetris       GB           1989.0
#
#           Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0        Sports  Nintendo     41.36     28.96      3.77         8.45
# 1      Platform  Nintendo     29.08      3.58      6.81         0.77
# 2        Racing  Nintendo     15.68     12.76      3.79         3.29
# 3        Sports  Nintendo     15.61     10.93      3.28         2.95
# 4  Role-Playing  Nintendo     11.27      8.89     10.22         1.00
# 5        Puzzle  Nintendo     23.20      2.26      4.22         0.58
#
# ...

# %%
Video_Games_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
Video_Games_df.loc[(Video_Games_df['Year_of_Release'] == 2006) & (Video_Games_df['Publisher'] == 'Nintendo')]
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 20                         Pokemon Diamond/Pokemon Pearl       DS
# 107               The Legend of Zelda: Twilight Princess      Wii
# 384                                      Clubhouse Games       DS
# 403    English Training: Have Fun Improving Your Skills!       DS
# 446                            Personal Trainer: Cooking       DS
# 503                              WarioWare: Smooth Moves      Wii
# 544                                    Yoshi's Island DS       DS
# 764                                       Pokemon Ranger       DS
# 787                                            Tetris DS       DS
# 879                                   Kirby Squeak Squad       DS
# ...

# %%
Video_Games_df.loc[(Video_Games_df['Year_of_Release'] == 2006) | (Video_Games_df['Publisher'] == 'Nintendo')]
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# ...                                                  ...      ...
# 16656                                   Fast Racing Neo      WiiU
# 16657  Nintendogs and Cats Golden Retriever and New F...      3DS
# 16665                                    Bookworm Deluxe       PC
# 16683                                        XI Coliseum      PSP
# 16715                                   LMA Manager 2007     X360
#
#        Year_of_Release         Genre                    Publisher  NA_Sales  \
# 0               2006.0        Sports                     Nintendo     41.36
# ...

# %%
Video_Games_df.loc[(Video_Games_df['Genre'] == 'Racing') & (Video_Games_df['Global_Sales'] > 10)]
# Out:
#                       Name Platform  Year_of_Release   Genre  \
# 2           Mario Kart Wii      Wii           2008.0  Racing
# 11           Mario Kart DS       DS           2005.0  Racing
# 28  Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 40            Mario Kart 7      3DS           2011.0  Racing
# 48          Gran Turismo 4      PS2           2004.0  Racing
# 52            Gran Turismo       PS           1997.0  Racing
# 54          Gran Turismo 5      PS3           2010.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2                      Nintendo     15.68     12.76      3.79         3.29
# 11                     Nintendo      9.71      7.47      4.13         1.90
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 40                     Nintendo      5.03      4.02      2.69         0.91
# 48  Sony Computer Entertainment      3.01      0.01      1.10         7.53
# ...

# %%
Video_Games_df.loc[Video_Games_df['Genre'] == 'Racing', 'Genre'] = 'Race'
