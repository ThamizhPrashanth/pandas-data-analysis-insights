# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamizhPrashanth/pandas-data-analysis-insights/blob/main/Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
DataFrame = pd.read_csv("/content/Pokemon.csv")

# %%
DataFrame

# %%
DataFrame.head(5)

# %%
DataFrame.tail(5)

# %%
DataFrame.columns  # To Read Headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
DataFrame['Name'] # To Read Each Specififc column
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
DataFrame['Name'][0:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
DataFrame[['Name', 'Type 1', 'HP']][0:5]
# Out:
#                     Name Type 1  HP
# 0              Bulbasaur  Grass  45
# 1                Ivysaur  Grass  60
# 2               Venusaur  Grass  80
# 3  VenusaurMega Venusaur  Grass  80
# 4             Charmander   Fire  39

# %%
DataFrame.iloc[1] # To Read Each Row
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
DataFrame.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
DataFrame.iloc[2,1]  # To Read Specific Location From a row Syntx is row , column we need
# Out:
# 'Venusaur'

# %%
DataFrame.loc[DataFrame['Type 1'] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
#DataFrame.loc[[DataFrame['Type 1'] == "Fire",DataFrame['Legendary'] == "False"]]

# %%
DataFrame.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
DataFrame.sort_values('Name', ascending=False)

# %%
DataFrame.sort_values(['Type 1', 'HP'], ascending=False)
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 351  321    Wailord  Water     NaN    500  170      90       45       90
# 655  594  Alomomola  Water     NaN    470  165      75       80       40
# 142  131     Lapras  Water     Ice    535  130      85       80       85
# 145  134   Vaporeon  Water     NaN    525  130      65       60      110
# 350  320    Wailmer  Water     NaN    400  130      70       35       70
# ..   ...        ...    ...     ...    ...  ...     ...      ...      ...
# 314  290    Nincada    Bug  Ground    266   31      45       90       30
# 462  415     Combee    Bug  Flying    244   30      30       42       30
# 603  543   Venipede    Bug  Poison    260   30      45       59       30
# 230  213    Shuckle    Bug    Rock    505   20      10      230       10
# 316  292   Shedinja    Bug   Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# 351       45     60           3      False
# ...

# %% [markdown]
# **MAKING CHANGES TO THE DATA**

# %%
DataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
DataFrame['Total_values'] = DataFrame['HP'] + DataFrame['Defense'] + DataFrame['Sp. Atk'] + DataFrame['Sp. Def'] + DataFrame['Speed'] + DataFrame['Attack']

# Adding a New Column

# %%
DataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    269  45      49       49
# 1  2                Ivysaur  Grass  Poison    343  60      62       63
# 2  3               Venusaur  Grass  Poison    443  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    525  80     100      123
# 4  4             Charmander   Fire     NaN    257  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_values
# 0       65       65     45           1      False           318
# 1       80       80     60           1      False           405
# 2      100      100     80           1      False           525
# 3      122      120     80           1      False           625
# 4       60       50     65           1      False           309

# %%
DataFrame.drop(columns=['Total'])  # To Drop a Column
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_values
# ...

# %%
DataFrame['Total'] = DataFrame.iloc[:, 5:11].sum(axis=1)

# %%
DataFrame
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
DataFrame
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
DataFrame.to_csv('modified.csv', index=False) # Saving our  modified file

# %%
DataFrame.drop(columns=['Total'])

# %% [markdown]
# **FILTERING THE DATA**

# %%
DataFrame.loc[DataFrame['Type 1'] == 'Grass'] # Filtering Single & Multiple Datas

# %%
DataFrame.loc[(DataFrame['Type 1'] == 'Grass') &  (DataFrame['Type 2'] == 'Poison')]

# %%
#DataFrame.loc[(DataFrame['Type 1'] == 'Grass') |  (DataFrame['Type 2'] == 'Poison')] -- OR condition

# %%
# DataFrame.loc[(DataFrame['Type 1'] == 'Grass') &  (DataFrame['HP']> 70)]

# %%
New_Dataframe = DataFrame.loc[(DataFrame['Type 1'] == 'Grass') &  (DataFrame['Type 2'] == 'Poison')]

# Also now we can save the new DF as well
New_Dataframe.to_csv("new_modified.csv")

# %%
New_Dataframe
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
New_Dataframe = New_Dataframe.reset_index()

# %%
New_Dataframe
# Out:
#     index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0       0    1              Bulbasaur  Grass  Poison    318   45      49
# 1       1    2                Ivysaur  Grass  Poison    405   60      62
# 2       2    3               Venusaur  Grass  Poison    525   80      82
# 3       3    3  VenusaurMega Venusaur  Grass  Poison    625   80     100
# 4      48   43                 Oddish  Grass  Poison    320   45      50
# 5      49   44                  Gloom  Grass  Poison    395   60      65
# 6      50   45              Vileplume  Grass  Poison    490   75      80
# 7      75   69             Bellsprout  Grass  Poison    300   50      75
# 8      76   70             Weepinbell  Grass  Poison    390   65      90
# 9      77   71             Victreebel  Grass  Poison    490   80     105
# 10    344  315                Roselia  Grass  Poison    400   50      60
# 11    451  406                  Budew  Grass  Poison    280   40      30
# ...

# %%
DataFrame.loc[(DataFrame['Name'].str.contains('Mega'))] # Filtering out the names which has Mega

# %%
#DataFrame.loc[DataFrame['Name'].str.contains('Mega')] # Filtering out the names which doesnt contain  Mega

# %%
DataFrame.loc[DataFrame['Name'].str.contains('Mega')]

# %%
import re

# %%
DataFrame.loc[DataFrame['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]  # Filtering out the type 1 contains whether grass or fire and ignoring the caps also

# %%
DataFrame.loc[DataFrame['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)] # Filtering the names starts with pi and can end with any characters

# %% [markdown]
# **CONDITIONAL CHANGES**

# %%
DataFrame.loc[DataFrame['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
DataFrame.loc[DataFrame['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

# %%
DataFrame.loc[DataFrame['Type 1'] == 'Fire', 'Legendary'] = True

# %%
DataFrame =pd.read_csv("/content/modified.csv")

# %%
DataFrame.loc[DataFrame['Total'] > 500,['Generation', 'Legendary']] = ['Test Value 1' , 'Test Value 2']

# %%
DataFrame
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
DataFrame = pd.read_csv("/content/modified.csv")

# %%
DataFrame

# %% [markdown]
# **Aggregate Stats (GroupBy)**

# %%
DataFrame.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)

# %%
DataFrame.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)

# %%
DataFrame.groupby(['Type 1']).mean().sort_values('HP', ascending=False)

# %%
DataFrame.groupby(['Type 1']).sum()

# %%
DataFrame.groupby(['Type 1']).count()

# %%
DataFrame['count'] = 1

# %%
DataFrame.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
DataFrame.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
